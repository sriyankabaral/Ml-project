# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("C:/Users/shahi/Desktop/Python exercise/heartattack/heart.csv")

df.head()
df.describe()
df.isnull().values.any()
df['sex'].value_counts()
print(df)
dfheart=df[df['output']==1]
print(dfheart)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
dfheart=df[df['output']==1]
print(dfheart)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 160   56    1   1     120   240    0        1       169     0      0.0    0
# 161   55    0   1     132   342    0        1       166     0      1.2    2
# 162   41    1   1     120   157    0        1       182     0      0.0    2
# 163   38    1   2     138   175    0        1       173     0      0.0    2
# 164   38    1   2     138   175    0        1       173     0      0.0    2
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
dfheart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
dfheart['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 160    56
# 161    55
# 162    41
# 163    38
# 164    38
# Name: age, Length: 165, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(dfheart['age'])
# Out:
# (array([ 1.,  8., 25., 21., 29., 31., 16., 21., 11.,  2.]),
#  array([29. , 33.7, 38.4, 43.1, 47.8, 52.5, 57.2, 61.9, 66.6, 71.3, 76. ]),
#  <BarContainer object of 10 artists>)

# %%
dfheart=df[df['output']==1]
dfnoheart=df[df['output']==0]
dfnoheart['thalachh'].describe()
# Out:
# count    138.000000
# mean     139.101449
# std       22.598782
# min       71.000000
# 25%      125.000000
# 50%      142.000000
# 75%      156.000000
# max      195.000000
# Name: thalachh, dtype: float64

# %%
dfheart['thalachh'].describe()
# Out:
# count    165.000000
# mean     158.466667
# std       19.174276
# min       96.000000
# 25%      149.000000
# 50%      161.000000
# 75%      172.000000
# max      202.000000
# Name: thalachh, dtype: float64

# %%
box=[dfheart['thalachh'],dfnoheart['thalachh']]
plt.boxplot(box,labels=["heart","noheart"] , positions=[2, 4], widths=1.5, patch_artist=True,
                showmeans=False, showfliers=False,
                medianprops={"color": "white", "linewidth": 0.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "C0", "linewidth": 1.5},
                capprops={"color": "C0", "linewidth": 1.5})
# Out:
# C:\Users\shahi\AppData\Local\Temp\ipykernel_23600\697003071.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(box,labels=["heart","noheart"] , positions=[2, 4], widths=1.5, patch_artist=True,
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bef5d108f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bef5d27d70>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x2bef5ccb890>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2bef5d28260>,
# ...
#  'fliers': [],
#  'means': []}

# %%
import pandas as pd
df = pd.read_csv("C:/Users/shahi/Desktop/Python exercise/heartattack/heart.csv")
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
import pandas as pd

import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv("C:/Users/shahi/Desktop/Python exercise/heartattack/heart.csv")
# Compute the correlation matrix
correlation_matrix = data.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exng      0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slp      -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# caa       0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thall     0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Plot the heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix,annot = True, cmap='coolwarm', linewidths=0.5)
#plt.title('Correlation Matrix Heatmap')
#plt.show()
# Out:
# <Axes: >

# %%
px.imshow(df.corr(),title="Correlation Plot of the Heart Failure Prediction")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_54.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import seaborn as sns
import matplotlib.pyplot as plt



# Creating the KDE plot
sns.kdeplot(data)

# Display the plot
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.violinplot(data)
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
sns.pairplot(data , hue='output')

# %%
plt.figure(figsize=(12,10))
sns.stripplot(df)
# Out:
# <Axes: >

# %%
import plotly.express as px

# %%
# %matplotlib inline
import plotly.express as px
import plotly.io as pio

pio.renderers.default = 'iframe_connected'  # Using iframe for connected Jupyter kernel

# Plot code
fig=px.histogram(df, 
                 x="output",
                 color="sex",
                 #hover_data=df.columns,
                 title="Distribution of Heart Diseases",
                 barmode="group")
                
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_46.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
px.histogram(data,x='cp',color='sex')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_47.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
px.box(data,y='thalachh',x='output')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_48.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
